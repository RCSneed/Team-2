-- %%
%%pyspark
#The code below is a python script to turn the tables into a functioning python dataframe.
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Sanitized_Refund_Lakehouse").getOrCreate()

df = spark.read.table("SAN_RecipientFeedback")
df.show()
-- Out:
-- StatementMeta(, dcfe4615-3626-4c9b-aca8-f2e23684f416, 8, Finished, Available, Finished)
-- +------------+----------+----------+-----+--------------------------------+
-- |RecipientsId|FeedbackId| CreatedOn|Stars|_IsFeedbackMessageAvailable_Flag|
-- +------------+----------+----------+-----+--------------------------------+
-- |      151336|     11432|2024-05-27|    2|                             Yes|
-- |      129007|     10286|2024-05-04|    2|                             Yes|
-- |      135253|     10483|2024-05-04|    2|                             Yes|
-- |      229067|     17676|2024-08-25|    2|                             Yes|
-- |      258516|     19805|2024-09-19|    2|                             Yes|
-- |      256970|     19625|2024-09-19|    2|                             Yes|
-- |      263815|     20061|2024-09-21|    2|                             Yes|
-- |      282438|     21732|2024-10-15|    2|                             Yes|
-- |      115868|      8850|2024-04-05|    2|                             Yes|
-- |      112044|      8453|2024-04-02|    2|                             Yes|
-- |      112472|      8456|2024-04-01|    2|                             Yes|
-- |      110351|      8312|2024-03-30|    2|                             Yes|
-- |      135957|     10477|2024-05-07|    2|                             Yes|
-- |      122164|      9272|2024-04-13|    2|                             Yes|
-- |       56461|      3913|2024-01-10|    2|                             Yes|
-- |       70970|      4939|2024-02-02|    2|                             Yes|
-- |       93931|      6955|2024-03-06|    2|                             Yes|
-- |       88848|      6538|2024-02-27|    2|                             Yes|
-- |       82909|      6036|2024-02-18|    2|                             Yes|
-- |       78067|      5697|2024-02-09|    2|                             Yes|
-- +------------+----------+----------+-----+--------------------------------+
-- only showing top 20 rows

-- %%
-- Welcome to your new notebook
-- Type here in the cell editor to add code!
-- This SQL query is a generic query for the sake of showing access and my ability to query
SELECT * FROM SAN_Disbursements
WHERE TotalAmount BETWEEN 1000 and 6000
AND DisbursementStatusName = 'Revoked';
-- Out:
-- StatementMeta(, dcfe4615-3626-4c9b-aca8-f2e23684f416, 5, Finished, Available, Finished)
-- <Spark SQL result set with 118 rows and 10 fields>
